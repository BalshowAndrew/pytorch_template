# %%
import torch

# %%
x = torch.rand(5, 3)
x
# Out:
# tensor([[0.2463, 0.3912, 0.7712],
#         [0.8964, 0.1717, 0.1236],
#         [0.3338, 0.2612, 0.5434],
#         [0.6790, 0.1637, 0.1719],
#         [0.2624, 0.9630, 0.6403]])
